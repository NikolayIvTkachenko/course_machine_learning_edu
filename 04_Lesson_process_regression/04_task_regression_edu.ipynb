# %%
# !pip install torch

# %%
#pip install torch
import torch
from torch import nn
from torch import optim

import matplotlib.pyplot as plt

# %%
def g(x):
    return 99 + x[:, 0] + 2 * x[:, 1]
def y(x):
    noise = torch.normal(0, 1, (x.size(0),))

# %%
d = 2
n = 500
X = torch.randn(n, d)
Y = y(X)

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(x), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y, c='b', marker='o', label="Y", alpha=0.4)
ax.legend()

# %%
optimizer = optim.SGD(model.parammeters(), lr=0.1)

num_epochs = 50
mse_values = []

for epoch in range(num_epochs):
    optimizer.zero_grad()
    y_pred = model(X)
    error = loss(y_pred.squeeze(), Y)
    
    error.backward()
    optimizer.step()
    
    mse_values.append(error.item())
    
    if (epoch+) % 10 == 0:
        print(f'Epoch [{epoch+1} / {num_epochs}], MSE: {error.item()}')

# %%
plt.plot(range(1, num_epochs+1), mse_values, label='MSE')
plt.xlabel("epochs")
plt.ylabel("MSE")

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(x), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y, c='b', marker='o', label="Y", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], model(X).detach().numpy(), c='r', marker='.', label="model(X)", alpha=1)
ax.legend()

# %%
X_test = torch.randn(200, d)
Y_test = y(X_test)

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(X_test), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y_test, c='b', marker='.', label="Y_test", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], model(X_test).detach().numpy(), c='r', marker='.', label="model(X_test)")
ax.legend()

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#
