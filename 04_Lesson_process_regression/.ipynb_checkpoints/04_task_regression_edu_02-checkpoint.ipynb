# %%
#

# %%
import torch
from torch import nn
from torch import optim

import matplotlib.pyplot as plt

# %%
def g(x):
    return x[:, 0] + 2 * x[:, 1]
def y(x):
    noise = torch.normal(0, 1, (x.size(0),))
    return g(x) + noise

# %%
d = 2
n = 500
X = torch.randn(n, d)
Y = y(X)

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(x), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y, c='b', marker='o', label="Y", alpha=0.4)
ax.legend()

# %%
# Аналитическое решение
w = ((X.T @ X).inverse() @ (X.T @ Y))

# %%
Y_pred = X @ w.T

# %%
print(f"MSE {loss(Y_pred, Y)}")

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(x), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y, c='b', marker='o', label="Y", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y_pred, c='r', marker='.', label="$Xw^T$", alpha=1)
ax.legend()

# %%
# Градиентый метод

# %%
def gradient_descent(X, Y, learning_rate=0.1, n_iterations=100):
    w = torch.randn(X.size(1))
    mse_history = []
    w_history = []
    
    for iteration in range (n_iterations):
        g = 2 / X.size(0) * (X.T @ (X @ w.T - Y))
        w = w -learning_rate * g
        
        mse_history.append(loss(X @ w.T, Y))
        w_history.append([w[0], w[1]])
    return w, mse_history, w_history

# %%
w, mse_history, w_history = gradient_descent(X, Y)

# %%
# Градиент исходного отображение и значений, предсказанных моделью

# %%
Y_pred = (X @ w.T).squeeze()

# %%
print(f"MMSE: {loss(Y_pred, Y)}")

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], g(X), c='gray', marker='o', label="true", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y, c='b', marker='.', label="Y", alpha=0.4)
ax.scatter(X[:, 0], X[:, 1], Y_pred, c='r', marker='.', label="$Xw^T$")
ax.legend()

# %%
#

# %%
#

# %%
#

# %%
#
