# %%
import torch
import numpy as np
import pandas as pd
import matplotli.pyplot as plt

from torch import nn
from torch import optim

# %%
# Целевая функция x * sin(x) + c

# %%
def g(x):
    C = 100
    return x**2 * np.sin(x) + C

def y(x):
    sigma = 2
    eps = torch
